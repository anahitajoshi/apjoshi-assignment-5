# %%
import numpy as np
import pandas as pd

# %%
class KNN:
    def __init__(self, k=3, distance_metric='euclidean', batch_size=100):
        self.k = k
        self.distance_metric = distance_metric
        self.batch_size = batch_size

    def fit(self, X, y):
        print(f"Training KNN with k={self.k} on training data...")
        self.X_train = X
        self.y_train = y
        print(f"Training completed.")

    def predict(self, X):
        print(f"Making predictions for {len(X)} test points...")
        predictions = []
        num_test = X.shape[0]

        for i in range(0, num_test, self.batch_size):
            X_batch = X[i:i + self.batch_size]
            distances = self.compute_distance(X_batch)

            for dist in distances:
                k_indices = np.argsort(dist)[:self.k]
                k_nearest_labels = self.y_train[k_indices].astype(int)
                majority_vote = np.argmax(np.bincount(k_nearest_labels))
                predictions.append(majority_vote)

        print(f"Predictions completed.")
        return predictions

    def compute_distance(self, X_test):
        if self.distance_metric == 'euclidean':
            distances = np.sqrt(np.sum((self.X_train - X_test[:, np.newaxis]) ** 2, axis=2))
            return distances
        else:
            raise ValueError("Unsupported distance metric")

# %%
def preprocess_data(train_path, test_path):
    print("Loading and preprocessing data...")
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)

    train_data = train_data.drop(['CustomerId', 'Surname'], axis=1)
    test_data = test_data.drop(['CustomerId', 'Surname'], axis=1)

    train_data['Geography'] = train_data['Geography'].astype('category').cat.codes
    train_data['Gender'] = train_data['Gender'].astype('category').cat.codes
    test_data['Geography'] = test_data['Geography'].astype('category').cat.codes
    test_data['Gender'] = test_data['Gender'].astype('category').cat.codes

    X_train = train_data.drop('Exited', axis=1).values
    y_train = train_data['Exited'].values
    X_test = test_data.values

    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)

    X_train = (X_train - mean) / std
    X_test = (X_test - mean) / std

    print("Data preprocessing completed.")
    return X_train, y_train, X_test

# %%
def cross_validate(X, y, knn, n_splits=5):
    print("Starting cross-validation...")
    n = len(X)
    fold_size = n // n_splits
    indices = np.arange(n)
    np.random.shuffle(indices)

    accuracy_scores = []

    for fold in range(n_splits):
        print(f"Processing fold {fold + 1} of {n_splits}...")
        val_start = fold * fold_size
        val_end = val_start + fold_size if fold != n_splits - 1 else n
        val_indices = indices[val_start:val_end]
        train_indices = np.concatenate([indices[:val_start], indices[val_end:]])

        X_train, y_train = X[train_indices], y[train_indices]
        X_val, y_val = X[val_indices], y[val_indices]

        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_val)

        accuracy = np.mean(y_pred == y_val)
        accuracy_scores.append(accuracy)

        print(f"Fold {fold + 1} accuracy: {accuracy:.4f}")

    print("Cross-validation completed.")
    return np.mean(accuracy_scores)

# %%
X, y, X_test = preprocess_data('/content/train.csv', '/content/test.csv')

knn = KNN(k=5, distance_metric='euclidean')

cv_scores = cross_validate(X, y, knn)
print("Cross-validation scores:", cv_scores)

best_k = 5
best_score = 0
for k in range(1, 20):
    print(f"Evaluating k={k}...")
    knn = KNN(k=k, distance_metric='euclidean')
    cv_score = cross_validate(X, y, knn)
    print(f"k = {k}, Cross-validation accuracy = {cv_score:.4f}")

    if cv_score > best_score:
        best_score = cv_score
        best_k = k

print(f"Best k found: {best_k} with cross-validation accuracy: {best_score:.4f}")

print(f"Training final model with k={best_k} on full dataset...")
knn = KNN(k=best_k, distance_metric='euclidean')
knn.fit(X, y)
test_predictions = knn.predict(X_test)

pd.DataFrame({'id': pd.read_csv('/content/test.csv')['id'], 'Exited': test_predictions}).to_csv('submissions.csv', index=False)
print("Predictions saved successfully.")
# Out:
# Loading data...
# Loading and preprocessing data...
# Data preprocessing completed.
# Starting cross-validation with k=5...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8810
# Processing fold 2 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8680
# Processing fold 3 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8677
# Processing fold 4 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8590
# Processing fold 5 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8693
# Cross-validation completed.
# Cross-validation scores: 0.869
# Starting hyperparameter tuning...
# Evaluating k=1...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8497
# Processing fold 2 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8397
# Processing fold 3 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8383
# Processing fold 4 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8480
# Processing fold 5 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8387
# Cross-validation completed.
# k = 1, Cross-validation accuracy = 0.8429
# Evaluating k=2...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8567
# Processing fold 2 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8583
# Processing fold 3 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8587
# Processing fold 4 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8633
# Processing fold 5 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8460
# Cross-validation completed.
# k = 2, Cross-validation accuracy = 0.8566
# Evaluating k=3...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8620
# Processing fold 2 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8690
# Processing fold 3 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8633
# Processing fold 4 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8683
# Processing fold 5 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8613
# Cross-validation completed.
# k = 3, Cross-validation accuracy = 0.8648
# Evaluating k=4...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8700
# Processing fold 2 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8633
# Processing fold 3 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8533
# Processing fold 4 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8653
# Processing fold 5 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8670
# Cross-validation completed.
# k = 4, Cross-validation accuracy = 0.8638
# Evaluating k=5...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8637
# Processing fold 2 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8733
# Processing fold 3 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8710
# Processing fold 4 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8687
# Processing fold 5 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8753
# Cross-validation completed.
# k = 5, Cross-validation accuracy = 0.8704
# Evaluating k=6...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8703
# Processing fold 2 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8770
# Processing fold 3 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8680
# Processing fold 4 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8693
# Processing fold 5 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8677
# Cross-validation completed.
# k = 6, Cross-validation accuracy = 0.8705
# Evaluating k=7...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8697
# Processing fold 2 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8880
# Processing fold 3 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8763
# Processing fold 4 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8677
# Processing fold 5 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8697
# Cross-validation completed.
# k = 7, Cross-validation accuracy = 0.8743
# Evaluating k=8...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8703
# Processing fold 2 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8703
# Processing fold 3 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8727
# Processing fold 4 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8697
# Processing fold 5 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8760
# Cross-validation completed.
# k = 8, Cross-validation accuracy = 0.8718
# Evaluating k=9...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8717
# Processing fold 2 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8730
# Processing fold 3 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8810
# Processing fold 4 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8633
# Processing fold 5 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8707
# Cross-validation completed.
# k = 9, Cross-validation accuracy = 0.8719
# Evaluating k=10...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8790
# Processing fold 2 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8777
# Processing fold 3 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8743
# Processing fold 4 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8677
# Processing fold 5 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8697
# Cross-validation completed.
# k = 10, Cross-validation accuracy = 0.8737
# Evaluating k=11...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8703
# Processing fold 2 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8823
# Processing fold 3 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8717
# Processing fold 4 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8730
# Processing fold 5 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8723
# Cross-validation completed.
# k = 11, Cross-validation accuracy = 0.8739
# Evaluating k=12...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8673
# Processing fold 2 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8753
# Processing fold 3 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8650
# Processing fold 4 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8703
# Processing fold 5 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8793
# Cross-validation completed.
# k = 12, Cross-validation accuracy = 0.8715
# Evaluating k=13...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8737
# Processing fold 2 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8787
# Processing fold 3 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8593
# Processing fold 4 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8753
# Processing fold 5 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8777
# Cross-validation completed.
# k = 13, Cross-validation accuracy = 0.8729
# Evaluating k=14...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8790
# Processing fold 2 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8820
# Processing fold 3 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8677
# Processing fold 4 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8747
# Processing fold 5 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8680
# Cross-validation completed.
# k = 14, Cross-validation accuracy = 0.8743
# Evaluating k=15...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8627
# Processing fold 2 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8763
# Processing fold 3 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8743
# Processing fold 4 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8797
# Processing fold 5 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8750
# Cross-validation completed.
# k = 15, Cross-validation accuracy = 0.8736
# Evaluating k=16...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8760
# Processing fold 2 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8690
# Processing fold 3 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8667
# Processing fold 4 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8753
# Processing fold 5 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8713
# Cross-validation completed.
# k = 16, Cross-validation accuracy = 0.8717
# Evaluating k=17...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8753
# Processing fold 2 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8757
# Processing fold 3 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8703
# Processing fold 4 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8790
# Processing fold 5 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8757
# Cross-validation completed.
# k = 17, Cross-validation accuracy = 0.8752
# Evaluating k=18...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8740
# Processing fold 2 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8747
# Processing fold 3 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8717
# Processing fold 4 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8777
# Processing fold 5 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8577
# Cross-validation completed.
# k = 18, Cross-validation accuracy = 0.8711
# Evaluating k=19...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8730
# Processing fold 2 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8630
# Processing fold 3 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8727
# Processing fold 4 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8793
# Processing fold 5 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8823
# Cross-validation completed.
# k = 19, Cross-validation accuracy = 0.8741
# Best k found: 17 with cross-validation accuracy: 0.8752
# Training final model with k=17 on full dataset...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 10000 test points...
# Predictions completed.
# Saving predictions to submissions.csv...
# Predictions saved successfully.
